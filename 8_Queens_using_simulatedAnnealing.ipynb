# %%
import random
import math

def calculate_conflicts(board):
    """Calculates the number of conflicts between queens on the board."""
    conflicts = 0
    for i in range(len(board)):
        for j in range(i + 1, len(board)):
            if board[i] == board[j] or abs(board[i] - board[j]) == abs(i - j):
                conflicts += 1
    return conflicts

def generate_new_state(board):
    """Generates a neighboring solution by swapping two queens' positions."""
    new_state = list(board)
    idx1, idx2 = random.sample(range(len(board)), 2)
    new_state[idx1], new_state[idx2] = new_state[idx2], new_state[idx1]
    return new_state

def calculate_acceptance_prob(old_conflicts, new_conflicts, temp):
    """Calculates the probability of accepting a worse solution based on the temperature."""
    if new_conflicts < old_conflicts:
        return 1.0
    return math.exp((old_conflicts - new_conflicts) / temp)

def simulated_annealing_for_8queens(init_temp, cooling_factor, max_iter):
    """Solves the 8-queens problem using simulated annealing."""
    current_state = list(range(8))
    current_conflicts = calculate_conflicts(current_state)
    temperature = init_temp

    for iteration in range(max_iter):
        new_state = generate_new_state(current_state)
        new_conflicts = calculate_conflicts(new_state)

        acceptance_prob = calculate_acceptance_prob(current_conflicts, new_conflicts, temperature)
        if random.random() < acceptance_prob:
            current_state = new_state
            current_conflicts = new_conflicts

        print(f"Iteration {iteration + 1}: Cost = {current_conflicts}, Temperature = {temperature:.2f}, Acceptance Probability = {acceptance_prob:.4f}")

        temperature *= cooling_factor

        if current_conflicts == 0:
            print(f"Solution found at iteration {iteration + 1}!")
            break

    return current_state, current_conflicts

initial_temp = 100
cooling_factor = 0.95
max_iterations = 1000

final_state, final_conflicts = simulated_annealing_for_8queens(initial_temp, cooling_factor, max_iterations)

if final_conflicts == 0:
    print("Final solution found:")
    for i in range(8):
        row = ['-'] * 8
        row[final_state[i]] = 'Q'
        print(''.join(row))
else:
    print(f"Solution not found. Final cost: {final_conflicts}")

print("1BM22CS028")
print("AKASH K S")
# Out:
# Iteration 1: Cost = 18, Temperature = 100.00, Acceptance Probability = 1.0000
# Iteration 2: Cost = 11, Temperature = 95.00, Acceptance Probability = 1.0000
# Iteration 3: Cost = 5, Temperature = 90.25, Acceptance Probability = 1.0000
# Iteration 4: Cost = 8, Temperature = 85.74, Acceptance Probability = 0.9656
# Iteration 5: Cost = 7, Temperature = 81.45, Acceptance Probability = 1.0000
# Iteration 6: Cost = 5, Temperature = 77.38, Acceptance Probability = 1.0000
# Iteration 7: Cost = 10, Temperature = 73.51, Acceptance Probability = 0.9342
# Iteration 8: Cost = 7, Temperature = 69.83, Acceptance Probability = 1.0000
# Iteration 9: Cost = 10, Temperature = 66.34, Acceptance Probability = 0.9558
# Iteration 10: Cost = 8, Temperature = 63.02, Acceptance Probability = 1.0000
# Iteration 11: Cost = 5, Temperature = 59.87, Acceptance Probability = 1.0000
# Iteration 12: Cost = 4, Temperature = 56.88, Acceptance Probability = 1.0000
# Iteration 13: Cost = 9, Temperature = 54.04, Acceptance Probability = 0.9116
# Iteration 14: Cost = 8, Temperature = 51.33, Acceptance Probability = 1.0000
# Iteration 15: Cost = 6, Temperature = 48.77, Acceptance Probability = 1.0000
# Iteration 16: Cost = 8, Temperature = 46.33, Acceptance Probability = 0.9577
# Iteration 17: Cost = 8, Temperature = 44.01, Acceptance Probability = 1.0000
# Iteration 18: Cost = 10, Temperature = 41.81, Acceptance Probability = 0.9533
# Iteration 19: Cost = 6, Temperature = 39.72, Acceptance Probability = 1.0000
# Iteration 20: Cost = 3, Temperature = 37.74, Acceptance Probability = 1.0000
# Iteration 21: Cost = 6, Temperature = 35.85, Acceptance Probability = 0.9197
# Iteration 22: Cost = 4, Temperature = 34.06, Acceptance Probability = 1.0000
# Iteration 23: Cost = 4, Temperature = 32.35, Acceptance Probability = 1.0000
# Iteration 24: Cost = 2, Temperature = 30.74, Acceptance Probability = 1.0000
# Iteration 25: Cost = 4, Temperature = 29.20, Acceptance Probability = 0.9338
# Iteration 26: Cost = 4, Temperature = 27.74, Acceptance Probability = 1.0000
# Iteration 27: Cost = 8, Temperature = 26.35, Acceptance Probability = 0.8592
# Iteration 28: Cost = 7, Temperature = 25.03, Acceptance Probability = 1.0000
# Iteration 29: Cost = 3, Temperature = 23.78, Acceptance Probability = 1.0000
# Iteration 30: Cost = 7, Temperature = 22.59, Acceptance Probability = 0.8377
# Iteration 31: Cost = 6, Temperature = 21.46, Acceptance Probability = 1.0000
# Iteration 32: Cost = 3, Temperature = 20.39, Acceptance Probability = 1.0000
# Iteration 33: Cost = 3, Temperature = 19.37, Acceptance Probability = 1.0000
# Iteration 34: Cost = 2, Temperature = 18.40, Acceptance Probability = 1.0000
# Iteration 35: Cost = 4, Temperature = 17.48, Acceptance Probability = 0.8919
# Iteration 36: Cost = 4, Temperature = 16.61, Acceptance Probability = 1.0000
# Iteration 37: Cost = 4, Temperature = 15.78, Acceptance Probability = 1.0000
# Iteration 38: Cost = 4, Temperature = 14.99, Acceptance Probability = 0.9355
# Iteration 39: Cost = 9, Temperature = 14.24, Acceptance Probability = 0.7039
# Iteration 40: Cost = 8, Temperature = 13.53, Acceptance Probability = 1.0000
# Iteration 41: Cost = 4, Temperature = 12.85, Acceptance Probability = 1.0000
# Iteration 42: Cost = 2, Temperature = 12.21, Acceptance Probability = 1.0000
# Iteration 43: Cost = 4, Temperature = 11.60, Acceptance Probability = 0.8416
# Iteration 44: Cost = 7, Temperature = 11.02, Acceptance Probability = 0.7616
# Iteration 45: Cost = 4, Temperature = 10.47, Acceptance Probability = 1.0000
# Iteration 46: Cost = 4, Temperature = 9.94, Acceptance Probability = 1.0000
# Iteration 47: Cost = 2, Temperature = 9.45, Acceptance Probability = 1.0000
# Iteration 48: Cost = 4, Temperature = 8.97, Acceptance Probability = 0.8002
# Iteration 49: Cost = 4, Temperature = 8.53, Acceptance Probability = 1.0000
# Iteration 50: Cost = 4, Temperature = 8.10, Acceptance Probability = 1.0000
# Iteration 51: Cost = 7, Temperature = 7.69, Acceptance Probability = 0.6771
# Iteration 52: Cost = 8, Temperature = 7.31, Acceptance Probability = 0.8721
# Iteration 53: Cost = 8, Temperature = 6.94, Acceptance Probability = 0.2736
# Iteration 54: Cost = 4, Temperature = 6.60, Acceptance Probability = 1.0000
# Iteration 55: Cost = 6, Temperature = 6.27, Acceptance Probability = 0.7268
# Iteration 56: Cost = 3, Temperature = 5.95, Acceptance Probability = 1.0000
# Iteration 57: Cost = 6, Temperature = 5.66, Acceptance Probability = 0.5884
# Iteration 58: Cost = 5, Temperature = 5.37, Acceptance Probability = 1.0000
# Iteration 59: Cost = 7, Temperature = 5.10, Acceptance Probability = 0.6758
# Iteration 60: Cost = 5, Temperature = 4.85, Acceptance Probability = 1.0000
# Iteration 61: Cost = 3, Temperature = 4.61, Acceptance Probability = 1.0000
# Iteration 62: Cost = 3, Temperature = 4.38, Acceptance Probability = 1.0000
# Iteration 63: Cost = 2, Temperature = 4.16, Acceptance Probability = 1.0000
# Iteration 64: Cost = 3, Temperature = 3.95, Acceptance Probability = 0.7763
# Iteration 65: Cost = 3, Temperature = 3.75, Acceptance Probability = 0.7661
# Iteration 66: Cost = 3, Temperature = 3.56, Acceptance Probability = 0.7554
# Iteration 67: Cost = 3, Temperature = 3.39, Acceptance Probability = 0.7443
# Iteration 68: Cost = 5, Temperature = 3.22, Acceptance Probability = 0.5371
# Iteration 69: Cost = 5, Temperature = 3.06, Acceptance Probability = 1.0000
# Iteration 70: Cost = 5, Temperature = 2.90, Acceptance Probability = 1.0000
# Iteration 71: Cost = 5, Temperature = 2.76, Acceptance Probability = 1.0000
# Iteration 72: Cost = 5, Temperature = 2.62, Acceptance Probability = 1.0000
# Iteration 73: Cost = 5, Temperature = 2.49, Acceptance Probability = 1.0000
# Iteration 74: Cost = 4, Temperature = 2.36, Acceptance Probability = 1.0000
# Iteration 75: Cost = 4, Temperature = 2.25, Acceptance Probability = 0.2631
# Iteration 76: Cost = 3, Temperature = 2.13, Acceptance Probability = 1.0000
# Iteration 77: Cost = 4, Temperature = 2.03, Acceptance Probability = 0.6107
# Iteration 78: Cost = 4, Temperature = 1.93, Acceptance Probability = 0.5950
# Iteration 79: Cost = 4, Temperature = 1.83, Acceptance Probability = 0.0651
# Iteration 80: Cost = 4, Temperature = 1.74, Acceptance Probability = 1.0000
# Iteration 81: Cost = 3, Temperature = 1.65, Acceptance Probability = 1.0000
# Iteration 82: Cost = 3, Temperature = 1.57, Acceptance Probability = 1.0000
# Iteration 83: Cost = 3, Temperature = 1.49, Acceptance Probability = 1.0000
# Iteration 84: Cost = 3, Temperature = 1.42, Acceptance Probability = 1.0000
# Iteration 85: Cost = 5, Temperature = 1.35, Acceptance Probability = 0.2261
# Iteration 86: Cost = 5, Temperature = 1.28, Acceptance Probability = 0.2091
# Iteration 87: Cost = 3, Temperature = 1.21, Acceptance Probability = 1.0000
# Iteration 88: Cost = 3, Temperature = 1.15, Acceptance Probability = 0.0312
# Iteration 89: Cost = 3, Temperature = 1.10, Acceptance Probability = 1.0000
# Iteration 90: Cost = 3, Temperature = 1.04, Acceptance Probability = 1.0000
# Iteration 91: Cost = 3, Temperature = 0.99, Acceptance Probability = 0.3637
# Iteration 92: Cost = 4, Temperature = 0.94, Acceptance Probability = 0.3449
# Iteration 93: Cost = 4, Temperature = 0.89, Acceptance Probability = 0.1063
# Iteration 94: Cost = 1, Temperature = 0.85, Acceptance Probability = 1.0000
# Iteration 95: Cost = 1, Temperature = 0.81, Acceptance Probability = 0.0835
# Iteration 96: Cost = 1, Temperature = 0.77, Acceptance Probability = 0.0732
# Iteration 97: Cost = 3, Temperature = 0.73, Acceptance Probability = 0.0638
# Iteration 98: Cost = 3, Temperature = 0.69, Acceptance Probability = 0.0031
# Iteration 99: Cost = 3, Temperature = 0.66, Acceptance Probability = 0.2178
# Iteration 100: Cost = 3, Temperature = 0.62, Acceptance Probability = 1.0000
# Iteration 101: Cost = 3, Temperature = 0.59, Acceptance Probability = 1.0000
# Iteration 102: Cost = 3, Temperature = 0.56, Acceptance Probability = 0.1690
# Iteration 103: Cost = 3, Temperature = 0.53, Acceptance Probability = 0.1539
# Iteration 104: Cost = 1, Temperature = 0.51, Acceptance Probability = 1.0000
# Iteration 105: Cost = 1, Temperature = 0.48, Acceptance Probability = 0.0002
# Iteration 106: Cost = 1, Temperature = 0.46, Acceptance Probability = 0.0127
# Iteration 107: Cost = 1, Temperature = 0.44, Acceptance Probability = 0.0010
# Iteration 108: Cost = 1, Temperature = 0.41, Acceptance Probability = 1.0000
# Iteration 109: Cost = 1, Temperature = 0.39, Acceptance Probability = 0.0061
# Iteration 110: Cost = 1, Temperature = 0.37, Acceptance Probability = 0.0047
# Iteration 111: Cost = 1, Temperature = 0.35, Acceptance Probability = 0.0035
# Iteration 112: Cost = 1, Temperature = 0.34, Acceptance Probability = 0.0513
# Iteration 113: Cost = 0, Temperature = 0.32, Acceptance Probability = 1.0000
# Solution found at iteration 113!
# Final solution found:
# -Q------
# ---Q----
# -----Q--
# -------Q
# --Q-----
# Q-------
# ------Q-
# ----Q---
# 1BM22CS028
# AKASH K S
